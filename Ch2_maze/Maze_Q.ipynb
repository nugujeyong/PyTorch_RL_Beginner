# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#draw maze

fig = plt.figure(figsize = (5,5))
ax = plt.gca()

#draw redwall

plt.plot([1,1], [0,1], color='red', linewidth=2)
plt.plot([1,2], [2,2], color = 'red', linewidth =2 )
plt.plot([2,2], [2,1], color = 'red', linewidth = 2)
plt.plot([2,3], [1,1], color = 'red', linewidth = 2)

#states

plt.text(0.5, 2.5, 'S0', size=14, ha='center')
plt.text(1.5, 2.5, 'S1', size=14, ha='center')
plt.text(2.5, 2.5, 'S2', size = 14, ha= 'center')
plt.text(0.5, 1.5, 'S3', size = 14, ha = 'center')
plt.text(1.5, 1.5, 'S4', size=14, ha='center')
plt.text(2.5, 1.5, 'S5', size = 14, ha = 'center')
plt.text(0.5,0.5,'S6', size = 14, ha = 'center')
plt.text(1.5, 0.5, 'S7', size = 14, ha = 'center')
plt.text(2.5, 0.5, 'S8', size = 14, ha = 'center')
plt.text(0.5, 2.3, 'START', ha = 'center')
plt.text(2.5, 0.3, 'GOAL', ha = 'center')

# draw settings
ax.set_xlim(0,3)
ax.set_ylim(0,3)
plt.tick_params(axis='both', which='both', bottom=False, top=False,
               labelbottom=False, right=False, left=False, labelleft=False)

# draw agent
line, = ax.plot([0.5], [2.5], marker="o", color = 'g', markersize = 60)

# %%
# Initial Value of parameter theta_0
# Each row represents up, right, down, left
theta_0 = np.array([[np.nan, 1, 1, np.nan], #s0
                   [np.nan, 1, np.nan, 1], #s1
                   [np.nan, np.nan, 1, 1], #s2
                    [1, 1, 1, np.nan], #s3
                    [np.nan, np.nan, 1, 1], #s4
                    [1, np.nan, np.nan, np.nan], #s5
                    [1, np.nan, np.nan, np.nan], #s6
                    [1, 1, np.nan, np.nan] #s7
                   ]) #s8 does not have a policy because it is GOAL

[a,b] = theta_0.shape
Q = np.random.rand(a, b) * theta_0 * 0.1 # mult theta_0 for nan values

# %%
def simple_convert_into_pi_from_theta(theta):

    [m, n] = theta.shape
    pi = np.zeros((m, n))
    for i in range(0, m):
        pi[i, :] = theta[i, :]/np.nansum(theta[i, :])

    pi = np.nan_to_num(pi)

    return pi

pi_0 = simple_convert_into_pi_from_theta(theta_0)

# %%
# epsilon greedy algorithm

def get_action(s, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]

    # choose action

    if np.random.rand() < epsilon:
        # choose random action
        next_direction = np.random.choice(direction, p = pi_0[s,:])
    else:
        next_direction = direction[np.nanargmax(Q[s, :])]
    
    if next_direction == "up":
        action = 0
    elif next_direction == "right":
        action = 1
    elif next_direction == "down":
        action = 2
    elif next_direction == "left":
        action = 3
    
    return action

def get_s_next(s, a, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]
    next_direction = direction[a] #direction of action a

    if next_direction == "up":
        s_next = s - 3
    elif next_direction == "right":
        s_next = s + 1
    elif next_direction == "down":
        s_next = s + 3
    elif next_direction == "left":
        s_next = s - 1

    return s_next

# %%
def Q_learning(s,a,r,s_next,a_next,Q, eta, gamma):

    if s_next == 8: #terminal state
        Q[s, a] = Q[s, a] + eta * (r - Q[s, a])

    else:
        Q[s, a] = Q[s, a] + eta * (r + gamma * np.nanmax(Q[s_next, :]) - Q[s, a])

    return Q

# %%
def goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi):
    s = 0
    a = a_next = get_action(s, Q, epsilon, pi)
    s_a_history = [[0, np.nan]] 

    while(1):
        a = a_next
        s_a_history[-1][1] = a

        s_next = get_s_next(s, a, Q, epsilon, pi)
        s_a_history.append([s_next, np.nan])

        if s_next == 8:
            r = 1
            a_next = np.nan
        else:
            r = 0
            a_next = get_action(s_next,Q,epsilon,pi)

        Q = Q_learning(s, a, r, s_next, a_next, Q, eta, gamma)

        if s_next == 8:
            break
        else:
            s = s_next
    
    return [s_a_history ,Q]

# %%
# get out of maze using SARSA

eta = 0.1 #learning rate
gamma = 0.9 #decay
epsilon = 0.5 #initial epsilon value
v = np.nanmax(Q, axis = 1) #compute max value of Q
is_continue = True
episode = 1

V = []
V.append(np.nanmax(Q, axis= 1))

while is_continue:
    print("Episode: " + str(episode))

    epsilon = epsilon/2

    [s_a_history, Q] = goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0)

    new_v = np.nanmax(Q, axis = 1)
    print(np.sum(np.abs(new_v - v)))
   
    v = new_v
    V.append(v)
    print("It took " + str(len(s_a_history) - 1) + "steps to terminal state.")

    #iterate for 100 episodes
    episode = episode + 1
    if episode > 100:
        break
# Out:
# Episode: 1
# 0.031205687464429234
# It took 38steps to terminal state.
# Episode: 2
# 0.09472529643596037
# It took 4steps to terminal state.
# Episode: 3
# 0.09275037128788946
# It took 4steps to terminal state.
# Episode: 4
# 0.08972313906148686
# It took 4steps to terminal state.
# Episode: 5
# 0.08862415888847673
# It took 4steps to terminal state.
# Episode: 6
# 0.0874848291558716
# It took 4steps to terminal state.
# Episode: 7
# 0.08660871396367693
# It took 4steps to terminal state.
# Episode: 8
# 0.08571428069186349
# It took 4steps to terminal state.
# Episode: 9
# 0.08478822728167047
# It took 4steps to terminal state.
# Episode: 10
# 0.08381842756047224
# It took 4steps to terminal state.
# Episode: 11
# 0.08279441989468668
# It took 4steps to terminal state.
# Episode: 12
# 0.0817076848683963
# It took 4steps to terminal state.
# Episode: 13
# 0.08055176368488313
# It took 4steps to terminal state.
# Episode: 14
# 0.079322258895653
# It took 4steps to terminal state.
# Episode: 15
# 0.0780167506991589
# It took 4steps to terminal state.
# Episode: 16
# 0.0766346551470628
# It took 4steps to terminal state.
# Episode: 17
# 0.07517704491758607
# It took 4steps to terminal state.
# Episode: 18
# 0.07364644866589415
# It took 4steps to terminal state.
# Episode: 19
# 0.07204664117286749
# It took 4steps to terminal state.
# Episode: 20
# 0.07038243344377071
# It took 4steps to terminal state.
# Episode: 21
# 0.06865946943675724
# It took 4steps to terminal state.
# Episode: 22
# 0.06688403412598942
# It took 4steps to terminal state.
# Episode: 23
# 0.06506287603943842
# It took 4steps to terminal state.
# Episode: 24
# 0.06320304618479569
# It took 4steps to terminal state.
# Episode: 25
# 0.06131175432752303
# It took 4steps to terminal state.
# Episode: 26
# 0.05939624286191622
# It took 4steps to terminal state.
# Episode: 27
# 0.05746367797652516
# It took 4steps to terminal state.
# Episode: 28
# 0.055521057423790765
# It took 4steps to terminal state.
# Episode: 29
# 0.05357513393079394
# It took 4steps to terminal state.
# Episode: 30
# 0.05163235310907932
# It took 4steps to terminal state.
# Episode: 31
# 0.04969880461640286
# It took 4steps to terminal state.
# Episode: 32
# 0.0477801852753707
# It took 4steps to terminal state.
# Episode: 33
# 0.04588177284969802
# It took 4steps to terminal state.
# Episode: 34
# 0.044008409207174914
# It took 4steps to terminal state.
# Episode: 35
# 0.04216449165045666
# It took 4steps to terminal state.
# Episode: 36
# 0.04035397126532231
# It took 4steps to terminal state.
# Episode: 37
# 0.038580357215376504
# It took 4steps to terminal state.
# Episode: 38
# 0.036846725997792984
# It took 4steps to terminal state.
# Episode: 39
# 0.03515573476313977
# It took 4steps to terminal state.
# Episode: 40
# 0.03350963789088962
# It took 4steps to terminal state.
# Episode: 41
# 0.031910306098899166
# It took 4steps to terminal state.
# Episode: 42
# 0.0303592474484769
# It took 4steps to terminal state.
# Episode: 43
# 0.028857629685604957
# It took 4steps to terminal state.
# Episode: 44
# 0.027406303432757684
# It took 4steps to terminal state.
# Episode: 45
# 0.026005825814158223
# It took 4steps to terminal state.
# Episode: 46
# 0.024656484160045622
# It took 4steps to terminal state.
# Episode: 47
# 0.023358319492551516
# It took 4steps to terminal state.
# Episode: 48
# 0.02211114954721627
# It took 4steps to terminal state.
# Episode: 49
# 0.020914591130202775
# It took 4steps to terminal state.
# Episode: 50
# 0.019768081652132508
# It took 4steps to terminal state.
# Episode: 51
# 0.018670899715511502
# It took 4steps to terminal state.
# Episode: 52
# 0.017622184664220053
# It took 4steps to terminal state.
# Episode: 53
# 0.016620955030898665
# It took 4steps to terminal state.
# Episode: 54
# 0.015666125841593104
# It took 4steps to terminal state.
# Episode: 55
# 0.014756524757086331
# It took 4steps to terminal state.
# Episode: 56
# 0.013890907047273915
# It took 4steps to terminal state.
# Episode: 57
# 0.013067969409059188
# It took 4steps to terminal state.
# Episode: 58
# 0.01228636264985683
# It took 4steps to terminal state.
# Episode: 59
# 0.011544703268183243
# It took 4steps to terminal state.
# Episode: 60
# 0.010841583970255142
# It took 4steps to terminal state.
# Episode: 61
# 0.010175583167247315
# It took 4steps to terminal state.
# Episode: 62
# 0.009545273502101437
# It took 4steps to terminal state.
# Episode: 63
# 0.008949229457752117
# It took 4steps to terminal state.
# Episode: 64
# 0.008386034100503537
# It took 4steps to terminal state.
# Episode: 65
# 0.007854285013234041
# It took 4steps to terminal state.
# Episode: 66
# 0.007352599473272048
# It took 4steps to terminal state.
# Episode: 67
# 0.006879618929298892
# It took 4steps to terminal state.
# Episode: 68
# 0.0064340128306239475
# It took 4steps to terminal state.
# Episode: 69
# 0.006014481860732279
# It took 4steps to terminal state.
# Episode: 70
# 0.005619760625225512
# It took 4steps to terminal state.
# Episode: 71
# 0.0052486198422389
# It took 4steps to terminal state.
# Episode: 72
# 0.004899868081187808
# It took 4steps to terminal state.
# Episode: 73
# 0.0045723530933255985
# It took 4steps to terminal state.
# Episode: 74
# 0.004264962775157866
# It took 4steps to terminal state.
# Episode: 75
# 0.003976625803256417
# It took 4steps to terminal state.
# Episode: 76
# 0.0037063119765264885
# It took 4steps to terminal state.
# Episode: 77
# 0.0034530322994976714
# It took 4steps to terminal state.
# Episode: 78
# 0.0032158388377883096
# It took 4steps to terminal state.
# Episode: 79
# 0.002993824374513898
# It took 4steps to terminal state.
# Episode: 80
# 0.002786121894134519
# It took 4steps to terminal state.
# Episode: 81
# 0.0025919039180374304
# It took 4steps to terminal state.
# Episode: 82
# 0.0024103817140505024
# It took 4steps to terminal state.
# Episode: 83
# 0.0022408044000975513
# It took 4steps to terminal state.
# Episode: 84
# 0.002082457960321138
# It took 4steps to terminal state.
# Episode: 85
# 0.0019346641902291406
# It took 4steps to terminal state.
# Episode: 86
# 0.0017967795857599667
# It took 4steps to terminal state.
# Episode: 87
# 0.0016681941896147245
# It took 4steps to terminal state.
# Episode: 88
# 0.001548330406761056
# It took 4steps to terminal state.
# Episode: 89
# 0.0014366417996787284
# It took 4steps to terminal state.
# Episode: 90
# 0.0013326118726844083
# It took 4steps to terminal state.
# Episode: 91
# 0.0012357528535343887
# It took 4steps to terminal state.
# Episode: 92
# 0.0011456044794643239
# It took 4steps to terminal state.
# Episode: 93
# 0.0010617327938732268
# It took 4steps to terminal state.
# Episode: 94
# 0.0009837289589854636
# It took 4steps to terminal state.
# Episode: 95
# 0.0009112080890368857
# It took 4steps to terminal state.
# Episode: 96
# 0.0008438081078221416
# It took 4steps to terminal state.
# Episode: 97
# 0.0007811886337812934
# It took 4steps to terminal state.
# Episode: 98
# 0.0007230298952383141
# It took 4steps to terminal state.
# Episode: 99
# 0.0006690316778735772
# It took 4steps to terminal state.
# Episode: 100
# 0.0006189123060500457
# It took 4steps to terminal state.

# %%
from matplotlib import animation
from IPython.display import HTML
import matplotlib.cm as cm

def init():
    line.set_data([], [])
    return (line,)

def animate(i):
    line, = ax.plot([0.5], [2.5], marker="s",
                    color = cm.jet(V[i][0]), markersize=85) #s0

    line, = ax.plot([1.5], [2.5], marker="s",
                    color = cm.jet(V[i][1]), markersize=85) #s1

    line, = ax.plot([2.5], [2.5], marker="s",
                    color = cm.jet(V[i][2]), markersize=85) #s2

    line, = ax.plot([0.5], [1.5], marker="s",
                    color = cm.jet(V[i][3]), markersize=85) #s3

    line, = ax.plot([1.5], [1.5], marker="s",
                    color = cm.jet(V[i][4]), markersize=85) #s4

    line, = ax.plot([2.5], [1.5], marker="s",
                    color = cm.jet(V[i][5]), markersize=85) #s5

    line, = ax.plot([0.5], [0.5], marker="s",
                    color = cm.jet(V[i][6]), markersize=85) #s6

    line, = ax.plot([1.5], [0.5], marker="s",
                    color = cm.jet(V[i][7]), markersize=85) #s7

    line, = ax.plot([2.5], [0.5], marker="s",
                    color = cm.jet(1.0), markersize=85) #s8

    return (line,)


anim = animation.FuncAnimation(
    fig, animate, init_func=init, frames = len(V), interval = 200, repeat = False)

anim.save("maze_Qlearning.gif")
HTML(anim.to_jshtml())
# Out:
# MovieWriter ffmpeg unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img4c0d9351111e4f19a7b7e03898332897">
#   <div class="anim-controls">
#     <input id="_anim_slider4c0d9351111e4f19a7b7e03898332897" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim4c0d9351111e4f19a7b7e03898332897.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim4c0d9351111e4f19a7b7e03898332897.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim4c0d9351111e4f19a7b7e03898332897.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim4c0d9351111e4f19a7b7e03898332897.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim4c0d9351111e4f19a7b7e03898332897.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim4c0d9351111e4f19a7b7e03898332897.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim4c0d9351111e4f19a7b7e03898332897.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim4c0d9351111e4f19a7b7e03898332897.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim4c0d9351111e4f19a7b7e03898332897.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim4c0d9351111e4f19a7b7e03898332897.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select4c0d9351111e4f19a7b7e03898332897" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_4c0d9351111e4f19a7b7e03898332897"
#              checked>
#       <label for="_anim_radio1_4c0d9351111e4f19a7b7e03898332897">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_4c0d9351111e4f19a7b7e03898332897"
#              >
#       <label for="_anim_radio2_4c0d9351111e4f19a7b7e03898332897">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_4c0d9351111e4f19a7b7e03898332897"
#              >
#       <label for="_anim_radio3_4c0d9351111e4f19a7b7e03898332897">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img4c0d9351111e4f19a7b7e03898332897";
#     var slider_id = "_anim_slider4c0d9351111e4f19a7b7e03898332897";
#     var loop_select_id = "_anim_loop_select4c0d9351111e4f19a7b7e03898332897";
#     var frames = new Array(101);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy8QZhcZAAAU5UlEQVR4nO3deZQdZZnH8e8lTcgCGEIgKEgaMCyG\
# RSQScEFEEGEA2USEiSMKLogwbGfGDUdxZhCd46AyDCODgAwIsiiLyuKojIpCQBQEAR3CIiYkJCEJ\
# EBKcO3881fbNpTvpjrernq7+fs65p+mqas6Tys3vvvXU2281ms1mE0lSOmtVXYAkqW8GtCQlZUBL\
# UlIGtCQlZUBLUlIGtCQlZUBLUlIGtCQlZUBLUlIGtCQlZUBLUlIGtCQlZUBLUlIGtCQlZUBLUlIG\
# tCQlZUBLUlIGtCQlZUBLUlIGtCQlZUBLUlIGtCQlZUBLUlIGtCQlZUBLUlIGtCQlZUBLUlIGtCQl\
# ZUBLUlIGtCQlZUBLUlIGtCQlZUBLUlIGtCQlZUBLUlIGtCQlZUBLUlIGtCQlZUBLUlIGtCQlZUBL\
# UlIGtCQl1VV1AWti0qRJdHd3V
